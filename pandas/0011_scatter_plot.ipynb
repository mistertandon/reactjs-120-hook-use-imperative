# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %config IPCompleter.greedy = True

# %%
import pandas as pd
import numpy as np

# %%
whitewine_df = pd.read_csv('../csv_files/winequality-white.csv', sep = ';')
whitewine_df.head(n = 2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
# 1                 14.0                 132.0    0.994  3.3       0.49
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6

# %%
# Scatter plot quality vs 'volatile acidity'
whitewine_df.plot.scatter(x = 'quality', y = 'volatile acidity')

# %%
# Scatter plot quality vs 'citric acid'
whitewine_df.plot.scatter(x = 'quality', y = 'pH')

# %%
# Scatter plot quality vs 'residual sugar'
whitewine_df.plot.scatter(x = 'quality', y = 'residual sugar')

# %%
# Scatter plot quality vs 'chlorides'
whitewine_df.plot.scatter(x = 'quality', y = 'alcohol')
